# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# !pip install matplotlib seaborn pandas

# %% [markdown]
# # Beta - VAE

# %%
df_1 = pd.read_csv('checkpoints/log_beta_VAE_old.csv')
df_2 = pd.read_csv('checkpoints/log_beta_VAE.csv')

df = pd.concat([df_1, df_2], ignore_index=True)
del df_1, df_2

# %%
df
# Out:
#        step        loss       mig       sap      hsic  max_corr  quasi_ok
# 0       100  887.445251  0.047845  0.000000  0.051285  0.999979     False
# 1       200  967.385559  0.075089  0.000000  0.103615  0.999804     False
# 2       300  913.571960  0.052219  0.002500  0.111928  0.999603     False
# 3       400  872.854614  0.055339  0.000000  0.091964  0.999824     False
# 4       500  826.946411  0.049459  0.001316  0.112180  0.999559     False
# ..      ...         ...       ...       ...       ...       ...       ...
# 995   99600  482.251343  0.071855  0.009459  0.063556  0.986833     False
# 996   99700  477.959229  0.046776  0.006579  0.069032  0.989958     False
# 997   99800  705.288330  0.044225  0.006250  0.054041  0.987004     False
# 998   99900  443.536285  0.056472  0.005714  0.072430  0.980579     False
# 999  100000  526.456055  0.054941  0.003947  0.054801  0.987082     False
#
# [1000 rows x 7 columns]

# %%
#grafico academico via seaborn
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 4))
sns.lineplot(data=df, x='step', y='loss', color='darkblue')
# sns.lineplot(data=df, x='step', y='val_loss', label='Validation Loss', color='orange')
plt.title('Loss over Steps for Beta VAE')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.legend()
plt.show()
# df.plot(x='step', y='loss', label='Loss', figsize=(10, 5))
# Out:
# /tmp/ipykernel_2959540/407550610.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#grafico academico via seaborn
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 4))
sns.lineplot(data=df, x='step', y='hsic', color='darkblue')
# sns.lineplot(data=df, x='step', y='val_loss', label='Validation Loss', color='orange')
plt.title('HSIC over Steps for Beta VAE')
plt.xlabel('Step')
plt.ylabel('HSIC')
plt.legend()
plt.show()
# df.plot(x='step', y='loss', label='Loss', figsize=(10, 5))
# Out:
# /tmp/ipykernel_2959540/139825348.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#grafico academico via seaborn
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 4))
sns.lineplot(data=df, x='step', y='max_corr', color='darkblue')
# sns.lineplot(data=df, x='step', y='val_loss', label='Validation Loss', color='orange')
plt.title('max_corr over Steps for Beta VAE')
plt.xlabel('Step')
plt.ylabel('max_corr')
plt.legend()
plt.show()
# df.plot(x='step', y='loss', label='Loss', figsize=(10, 5))
# Out:
# /tmp/ipykernel_2959540/1165580706.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#grafico academico via seaborn
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 4))
sns.lineplot(data=df, x='step', y='mig', color='darkblue')
# sns.lineplot(data=df, x='step', y='val_loss', label='Validation Loss', color='orange')
plt.title('MIG over Steps for Beta VAE')
plt.xlabel('Step')
plt.ylabel('MIG')
plt.legend()
plt.show()
# df.plot(x='step', y='loss', label='Loss', figsize=(10, 5))
# Out:
# /tmp/ipykernel_2959540/2562601670.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#grafico academico via seaborn
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 4))
sns.lineplot(data=df, x='step', y='max_corr', color='darkblue')
# sns.lineplot(data=df, x='step', y='val_loss', label='Validation Loss', color='orange')
plt.title('max_corr over Steps for Beta VAE')
plt.xlabel('Step')
plt.ylabel('max_corr')
plt.legend()
plt.show()
# df.plot(x='step', y='loss', label='Loss', figsize=(10, 5))
# Out:
# /tmp/ipykernel_2959540/1165580706.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#grafico academico via seaborn
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 4))
sns.lineplot(data=df, x='step', y='sap', color='darkblue')
# sns.lineplot(data=df, x='step', y='val_loss', label='Validation Loss', color='orange')
plt.title('SAP over Steps for Beta VAE')
plt.xlabel('Step')
plt.ylabel('SAP')
plt.legend()
plt.show()
# df.plot(x='step', y='loss', label='Loss', figsize=(10, 5))
# Out:
# /tmp/ipykernel_2959540/1305322374.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
for col in df.columns:
    if col not in ['step', 'loss', 'quasi_ok']:
        df.plot(x='step', y=col, label=col, figsize=(10, 5))

# %%
df.quasi_ok.value_counts()
# Out:
# quasi_ok
# False    1000
# Name: count, dtype: int64
